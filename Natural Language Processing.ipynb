# %% [markdown]
# # NLP
# Find your favorite news source and grab the article text.
#
# 1. Show the most common words in the article.
# 2. Show the most common words under a part of speech. (i.e. NOUN: {'Bob':12, 'Alice':4,})
# 3. Find a subject/object relationship through the dependency parser in any sentence.
# 4. Show the most common Entities and their types.
# 5. Find Entites and their dependency (hint: entity.root.head)
# 6. Find the most similar words in the article

# %% [markdown]
# Note: Yes, the notebook from the video is not provided, I leave it to you to make your own :) it's your final assignment for the semester. Enjoy!

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\eabbo\anaconda3\lib\site-packages (3.3.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (0.7.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (20.4)
# Requirement already satisfied: jinja2 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (2.11.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (1.0.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (8.0.15)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (4.50.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (0.6.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (1.22.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (1.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (0.9.1)
# Requirement already satisfied: setuptools in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (50.3.1.post20201107)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (2.24.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (3.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (2.4.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\eabbo\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: six in c:\users\eabbo\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\eabbo\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\eabbo\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.7.4.3)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\eabbo\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\eabbo\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eabbo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\eabbo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\eabbo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\eabbo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)

# %%
# !python -m spacy download en
# Out:
# Requirement already satisfied: en-core-web-sm==3.3.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.3.0/en_core_web_sm-3.3.0-py3-none-any.whl#egg=en_core_web_sm==3.3.0 in c:\users\eabbo\anaconda3\lib\site-packages (3.3.0)
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in c:\users\eabbo\anaconda3\lib\site-packages (from en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.24.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.9)
# Requirement already satisfied: setuptools in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (50.3.1.post20201107)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.9.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.50.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.8.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.4.3)
# Requirement already satisfied: jinja2 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.11.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (20.4)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.6.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.22.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.7.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\eabbo\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\eabbo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\eabbo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eabbo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\eabbo\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.25.11)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\eabbo\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (7.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\eabbo\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.7.4.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\eabbo\anaconda3\lib\site-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\eabbo\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.4.7)
# Requirement already satisfied: six in c:\users\eabbo\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.15.0)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\eabbo\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (5.2.1)
# [!] As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the full
# pipeline package name 'en_core_web_sm' instead.
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2022-04-29 12:34:46.813795: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-04-29 12:34:46.813827: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import spacy
# import spacy.en.download
# spacy.en.download.download.en
from spacy.lang.en import English
processor = spacy.load('en_core_web_sm')

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Show the most common words in the article.

# %%
from collections import Counter # simple counter assist

# %%
# https://www.bbc.com/news/business-61258357

text = "Twitter, which this week agreed to be bought by billionaire Elon Musk, has said its user numbers grew faster than expected over the past year. Advertising revenue has also been rising, but by less than was forecast. Some observers have questioned Mr Musk's commercial judgement in buying Twitter, a platform that despite its high profile has not consistently made high returns. In the latest quarter it made a profit of $513m (£412m) on revenues of $1.2bn. Daily active users of the platform rose to 229 million, up from 199 million a year earlier, the company said, publishing its latest financial results. New users grew faster outside the US, by 18.1%, than in its home market where numbers were up 6.4% over the 12 months to the end of March. This week Twitter's board agreed a $44bn sale to Tesla boss, Mr Musk, the world's richest person, and a prolific user of the platform. In publishing its results, the firm said it was withdrawing all previously provided guidance over its immediate commercial outlook. However, it did say revenues had been affected by 'headwinds associated with the war in Ukraine'. Mr Musk's purchase is likely to take several months to complete, after which the company will be owned privately. While Mr Musk has not made clear his precise plans for the platform, he has spoken about reducing advertising, and cracking down on 'bot' or automated accounts. He has also prompted controversy by suggesting there may be a new approach to how Twitter moderates free speech."

# %%
twitter = processor(text)
twitter
# Out:
# Twitter, which this week agreed to be bought by billionaire Elon Musk, has said its user numbers grew faster than expected over the past year. Advertising revenue has also been rising, but by less than was forecast. Some observers have questioned Mr Musk's commercial judgement in buying Twitter, a platform that despite its high profile has not consistently made high returns. In the latest quarter it made a profit of $513m (£412m) on revenues of $1.2bn. Daily active users of the platform rose to 229 million, up from 199 million a year earlier, the company said, publishing its latest financial results. New users grew faster outside the US, by 18.1%, than in its home market where numbers were up 6.4% over the 12 months to the end of March. This week Twitter's board agreed a $44bn sale to Tesla boss, Mr Musk, the world's richest person, and a prolific user of the platform. In publishing its results, the firm said it was withdrawing all previously provided guidance over its immediate commercial outlook. However, it did say revenues had been affected by 'headwinds associated with the war in Ukraine'. Mr Musk's purchase is likely to take several months to complete, after which the company will be owned privately. While Mr Musk has not made clear his precise plans for the platform, he has spoken about reducing advertising, and cracking down on 'bot' or automated accounts. He has also prompted controversy by suggesting there may be a new approach to how Twitter moderates free speech.

# %%
tokens = [token.text for token in twitter if not token.is_punct if not token.is_stop] # needed to remove pun otherwise 'words' only showed up once
tokens[0:10]
# Out:
# ['Twitter',
#  'week',
#  'agreed',
#  'bought',
#  'billionaire',
#  'Elon',
#  'Musk',
#  'said',
#  'user',
#  'numbers']

# %%
freq = Counter(tokens)
freq.most_common()[0:10]
# Out:
# [('Musk', 5),
#  ('Twitter', 4),
#  ('Mr', 4),
#  ('platform', 4),
#  ('said', 3),
#  ('$', 3),
#  ('week', 2),
#  ('agreed', 2),
#  ('user', 2),
#  ('numbers', 2)]

# %% [markdown]
# ### 2. Show the most common words under a part of speech. (i.e. NOUN: {'Bob':12, 'Alice':4,})

# %%
pos = [token.pos_ for token in twitter if not token.is_punct if not token.is_stop]
pos[0:5], tokens[0:5]
# Out:
# (['PROPN', 'NOUN', 'VERB', 'VERB', 'NOUN'],
#  ['Twitter', 'week', 'agreed', 'bought', 'billionaire'])

# %%
df = pd.DataFrame({"pos": pos, "word": tokens})
df.head()
# Out:
#      pos         word
# 0  PROPN      Twitter
# 1   NOUN         week
# 2   VERB       agreed
# 3   VERB       bought
# 4   NOUN  billionaire

# %%
df['count'] = df.groupby('word')['word'].transform('count')
df = df.sort_values(['pos', 'count', 'word'], ascending = [True, False, True])
df.head(25) # shows words by pos and how many
# Out:
#      pos          word  count
# 23   ADJ    commercial      2
# 103  ADJ    commercial      2
# 29   ADJ          high      2
# 32   ADJ          high      2
# 34   ADJ        latest      2
# 60   ADJ        latest      2
# 63   ADJ           New      1
# 47   ADJ        active      1
# 122  ADJ         clear      1
# 61   ADJ     financial      1
# 140  ADJ          free      1
# 102  ADJ     immediate      1
# 114  ADJ        likely      1
# 136  ADJ           new      1
# 13   ADJ          past      1
# 123  ADJ       precise      1
# 91   ADJ      prolific      1
# 89   ADJ       richest      1
# 67   ADP       outside      1
# 11   ADV        faster      2
# 66   ADV        faster      2
# 46   ADV         Daily      1
# 31   ADV  consistently      1
# 56   ADV       earlier      1
# 99   ADV    previously      1

# %%
# convert to a list
list = df.values.tolist()
list[0:25]
# Out:
# [['ADJ', 'commercial', 2],
#  ['ADJ', 'commercial', 2],
#  ['ADJ', 'high', 2],
#  ['ADJ', 'high', 2],
#  ['ADJ', 'latest', 2],
#  ['ADJ', 'latest', 2],
#  ['ADJ', 'New', 1],
#  ['ADJ', 'active', 1],
#  ['ADJ', 'clear', 1],
#  ['ADJ', 'financial', 1],
#  ['ADJ', 'free', 1],
#  ['ADJ', 'immediate', 1],
#  ['ADJ', 'likely', 1],
#  ['ADJ', 'new', 1],
#  ['ADJ', 'past', 1],
#  ['ADJ', 'precise', 1],
#  ['ADJ', 'prolific', 1],
#  ['ADJ', 'richest', 1],
#  ['ADP', 'outside', 1],
#  ['ADV', 'faster', 2],
#  ['ADV', 'faster', 2],
#  ['ADV', 'Daily', 1],
#  ['ADV', 'consistently', 1],
#  ['ADV', 'earlier', 1],
#  ['ADV', 'previously', 1]]

# %%
# remove duplicates from list
new_list = []
for i in list:
    if i not in new_list:
        new_list.append(i)

new_list[0:25]
# Out:
# [['ADJ', 'commercial', 2],
#  ['ADJ', 'high', 2],
#  ['ADJ', 'latest', 2],
#  ['ADJ', 'New', 1],
#  ['ADJ', 'active', 1],
#  ['ADJ', 'clear', 1],
#  ['ADJ', 'financial', 1],
#  ['ADJ', 'free', 1],
#  ['ADJ', 'immediate', 1],
#  ['ADJ', 'likely', 1],
#  ['ADJ', 'new', 1],
#  ['ADJ', 'past', 1],
#  ['ADJ', 'precise', 1],
#  ['ADJ', 'prolific', 1],
#  ['ADJ', 'richest', 1],
#  ['ADP', 'outside', 1],
#  ['ADV', 'faster', 2],
#  ['ADV', 'Daily', 1],
#  ['ADV', 'consistently', 1],
#  ['ADV', 'earlier', 1],
#  ['ADV', 'previously', 1],
#  ['ADV', 'privately', 1],
#  ['NOUN', 'platform', 4],
#  ['NOUN', 'company', 2],
#  ['NOUN', 'months', 2]]

# %%
# group by pos
output = {}

for x, y, z in new_list:
    group = output.get(x, [])
    group.extend((y, z))
    output[x] = group

print(output)
# Out:
# {'ADJ': ['commercial', 2, 'high', 2, 'latest', 2, 'New', 1, 'active', 1, 'clear', 1, 'financial', 1, 'free', 1, 'immediate', 1, 'likely', 1, 'new', 1, 'past', 1, 'precise', 1, 'prolific', 1, 'richest', 1], 'ADP': ['outside', 1], 'ADV': ['faster', 2, 'Daily', 1, 'consistently', 1, 'earlier', 1, 'previously', 1, 'privately', 1], 'NOUN': ['platform', 4, 'company', 2, 'months', 2, 'numbers', 2, 'results', 2, 'revenues', 2, 'user', 2, 'users', 2, 'week', 2, 'year', 2, '44bn', 1, 'Advertising', 1, 'accounts', 1, 'advertising', 1, 'approach', 1, 'billionaire', 1, 'board', 1, 'boss', 1, 'bot', 1, 'controversy', 1, 'end', 1, 'firm', 1, 'guidance', 1, 'headwinds', 1, 'home', 1, 'judgement', 1, 'market', 1, 'observers', 1, 'outlook', 1, 'person', 1, 'plans', 1, 'profile', 1, 'profit', 1, 'purchase', 1, 'quarter', 1, 'returns', 1, 'revenue', 1, 'sale', 1, 'speech', 1, 'war', 1, 'world', 1], 'NUM': ['m', 2, 'million', 2, '1.2bn', 1, '12', 1, '18.1', 1, '199', 1, '229', 1, '412', 1, '513', 1, '6.4', 1], 'PROPN': ['Musk', 5, 'Mr', 4, 'Twitter', 4, 'Elon', 1, 'March', 1, 'Tesla', 1, 'Ukraine', 1], 'SCONJ': ['despite', 1], 'SYM': ['$', 3, '£', 1], 'VERB': ['said', 3, 'agreed', 2, 'grew', 2, 'publishing', 2, 'affected', 1, 'associated', 1, 'automated', 1, 'bought', 1, 'buying', 1, 'complete', 1, 'cracking', 1, 'expected', 1, 'forecast', 1, 'moderates', 1, 'owned', 1, 'prompted', 1, 'provided', 1, 'questioned', 1, 'reducing', 1, 'rising', 1, 'rose', 1, 'spoken', 1, 'suggesting', 1, 'withdrawing', 1]}

# %% [markdown]
# ### 3. Find a subject/object relationship through the dependency parser in any sentence.

# %%
def pr_tree(word, level):
    if word.is_punct:
        return
    for child in word.lefts:
        pr_tree(child, level+1)
        print('\t' * level + word.text + ' - ' + word.dep_)
        for child in word.rights:
            pr_tree(child, level+1)

# %%
for sentence in twitter.sents:
    pr_tree(sentence.root, 0)
    print('---------------------------------------------')
# Out:
# said - ROOT
# 		numbers - nsubj
# 		numbers - nsubj
# 	grew - ccomp
# said - ROOT
# 		numbers - nsubj
# 		numbers - nsubj
# 	grew - ccomp
# ---------------------------------------------
# 	revenue - nsubj
# rising - ROOT
# 	forecast - conj
# 	forecast - conj
# rising - ROOT
# 	forecast - conj
# 	forecast - conj
# rising - ROOT
# 	forecast - conj
# 	forecast - conj
# rising - ROOT
# 	forecast - conj
# 	forecast - conj
# ---------------------------------------------
# 	observers - nsubj
# questioned - ROOT
# 		Musk - poss
# 	judgement - dobj
# 	judgement - dobj
# questioned - ROOT
# 		Musk - poss
# 	judgement - dobj
# 	judgement - dobj
# ---------------------------------------------
# made - ROOT
# 	profit - dobj
# 	412 - dobj
# made - ROOT
# 	profit - dobj
# 	412 - dobj
# ---------------------------------------------
# 		users - nsubj
# 		users - nsubj
# 	rose - ccomp
# said - ROOT
# said - ROOT
# 	company - nsubj
# said - ROOT
# ---------------------------------------------
# 	users - nsubj
# grew - ROOT
# ---------------------------------------------
# 	week - npadvmod
# agreed - ROOT
# 	sale - dobj
# 		Musk - appos
# 				world - poss
# 			person - appos
# 				user - conj
# 				user - conj
# 			person - appos
# 				user - conj
# 				user - conj
# 		44bn - compound
# 	sale - dobj
# 		Musk - appos
# 				world - poss
# 			person - appos
# 				user - conj
# 				user - conj
# 			person - appos
# 				user - conj
# 				user - conj
# 	board - nsubj
# agreed - ROOT
# 	sale - dobj
# 		Musk - appos
# 				world - poss
# 			person - appos
# 				user - conj
# 				user - conj
# 			person - appos
# 				user - conj
# 				user - conj
# 		44bn - compound
# 	sale - dobj
# 		Musk - appos
# 				world - poss
# 			person - appos
# 				user - conj
# 				user - conj
# 			person - appos
# 				user - conj
# 				user - conj
# ---------------------------------------------
# said - ROOT
# 	withdrawing - ccomp
# 		guidance - dobj
# 			provided - amod
# 		guidance - dobj
# 	withdrawing - ccomp
# 		guidance - dobj
# 			provided - amod
# 		guidance - dobj
# said - ROOT
# 	withdrawing - ccomp
# 		guidance - dobj
# 			provided - amod
# 		guidance - dobj
# 	withdrawing - ccomp
# 		guidance - dobj
# 			provided - amod
# 		guidance - dobj
# 	firm - nsubj
# said - ROOT
# 	withdrawing - ccomp
# 		guidance - dobj
# 			provided - amod
# 		guidance - dobj
# 	withdrawing - ccomp
# 		guidance - dobj
# 			provided - amod
# 		guidance - dobj
# ---------------------------------------------
# say - ROOT
# 	affected - ccomp
# 	affected - ccomp
# 	affected - ccomp
# say - ROOT
# 	affected - ccomp
# 	affected - ccomp
# 	affected - ccomp
# say - ROOT
# 	affected - ccomp
# 	affected - ccomp
# 	affected - ccomp
# say - ROOT
# 	affected - ccomp
# 	affected - ccomp
# 	affected - ccomp
# ---------------------------------------------
# 		Musk - poss
# 	purchase - nsubj
# is - ROOT
# 	owned - advcl
# 		company - nsubjpass
# 	owned - advcl
# 	owned - advcl
# 	owned - advcl
# ---------------------------------------------
# 	made - advcl
# 		plans - dobj
# 		plans - dobj
# 		plans - dobj
# 		Musk - nsubj
# 	made - advcl
# 		plans - dobj
# 		plans - dobj
# 		plans - dobj
# 	made - advcl
# 		plans - dobj
# 		plans - dobj
# 		plans - dobj
# 	made - advcl
# 		plans - dobj
# 		plans - dobj
# 		plans - dobj
# spoken - ROOT
# spoken - ROOT
# spoken - ROOT
# spoken - ROOT
# ---------------------------------------------
# prompted - ROOT
# prompted - ROOT
# prompted - ROOT
# ---------------------------------------------

# %% [markdown]
# ### 4. Show the most common Entities and their types.

# %%
for entity in twitter.ents:
    print(entity, entity.label_, )
# Out:
# this week DATE
# Elon Musk PERSON
# the past year DATE
# Musk PERSON
# Twitter PRODUCT
# the latest quarter DATE
# 513 MONEY
# Daily DATE
# 229 million CARDINAL
# 199 million CARDINAL
# a year earlier DATE
# US GPE
# 18.1% PERCENT
# 6.4% PERCENT
# the 12 months DATE
# the end of March DATE
# Twitter PERSON
# 44bn MONEY
# Tesla ORG
# Musk PERSON
# Ukraine GPE
# Musk PERSON
# several months DATE
# Musk PERSON
# Twitter PRODUCT

# %% [markdown]
# ### 5. Find Entites and their dependency (hint: entity.root.head)

# %%
n = 0
for entity in twitter.ents:
    print("'", entity, "' ", "is dependent on ", "'", entity.root.head, "'", sep = '')
    n += 1
# Out:
# 'this week' is dependent on 'agreed'
# 'Elon Musk' is dependent on 'by'
# 'the past year' is dependent on 'over'
# 'Musk' is dependent on 'judgement'
# 'Twitter' is dependent on 'buying'
# 'the latest quarter' is dependent on 'In'
# '513' is dependent on 'of'
# 'Daily' is dependent on 'users'
# '229 million' is dependent on 'to'
# '199 million' is dependent on 'from'
# 'a year earlier' is dependent on 'from'
# 'US' is dependent on 'outside'
# '18.1%' is dependent on 'by'
# '6.4%' is dependent on 'up'
# 'the 12 months' is dependent on 'over'
# 'the end of March' is dependent on 'to'
# 'Twitter' is dependent on 'board'
# '44bn' is dependent on 'sale'
# 'Tesla' is dependent on 'boss'
# 'Musk' is dependent on 'sale'
# 'Ukraine' is dependent on 'in'
# 'Musk' is dependent on 'purchase'
# 'several months' is dependent on 'take'
# 'Musk' is dependent on 'made'
# 'Twitter' is dependent on 'moderates'

# %% [markdown]
# ### 6. Find the most similar words in the article

# %%
# used doc.ents from spaCy documentation to find similar words/phrases
similar_words = [(token_first.text, token_second.text, token_first.similarity(token_second)) for token_first in twitter.ents for token_second in twitter.ents]
similar_words[0:50]
# Out:
# <ipython-input-21-7cbf56c4964c>:2: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Span.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similar_words = [(token_first.text, token_second.text, token_first.similarity(token_second)) for token_first in twitter.ents for token_second in twitter.ents]
# [('this week', 'this week', 1.0),
#  ('this week', 'Elon Musk', 0.1362256109714508),
#  ('this week', 'the past year', 0.4012893736362457),
#  ('this week', 'Musk', 0.08003652095794678),
#  ('this week', 'Twitter', -0.0020605523604899645),
#  ('this week', 'the latest quarter', 0.26848894357681274),
#  ('this week', '513', -0.11720535904169083),
#  ('this week', 'Daily', -0.03588566556572914),
#  ('this week', '229 million', -0.048933278769254684),
#  ('this week', '199 million', -0.0656629130244255),
#  ('this week', 'a year earlier', 0.4542818069458008),
#  ('this week', 'US', 0.04240124300122261),
#  ('this week', '18.1%', 0.17094899713993073),
#  ('this week', '6.4%', 0.13086354732513428),
#  ('this week', 'the 12 months', 0.2084415853023529),
#  ('this week', 'the end of March', 0.2791098654270172),
#  ('this week', 'Twitter', 0.14400601387023926),
#  ('this week', '44bn', 0.027430834248661995),
#  ('this week', 'Tesla', -0.07456112653017044),
#  ('this week', 'Musk', 0.11970679461956024),
#  ('this week', 'Ukraine', -0.2031226009130478),
#  ('this week', 'Musk', 0.13531716167926788),
#  ('this week', 'several months', 0.22037017345428467),
#  ('this week', 'Musk', 0.1770239621400833),
#  ('this week', 'Twitter', 0.21021771430969238),
#  ('Elon Musk', 'this week', 0.1362256109714508),
#  ('Elon Musk', 'Elon Musk', 1.0),
#  ('Elon Musk', 'the past year', 0.18526223301887512),
#  ('Elon Musk', 'Musk', 0.5918982028961182),
#  ('Elon Musk', 'Twitter', 0.5335564017295837),
#  ('Elon Musk', 'the latest quarter', 0.06903451681137085),
#  ('Elon Musk', '513', 0.19692300260066986),
#  ('Elon Musk', 'Daily', 0.14220929145812988),
#  ('Elon Musk', '229 million', 0.3832981288433075),
#  ('Elon Musk', '199 million', 0.2247205227613449),
#  ('Elon Musk', 'a year earlier', 0.05400713160634041),
#  ('Elon Musk', 'US', 0.6133045554161072),
#  ('Elon Musk', '18.1%', 0.16585204005241394),
#  ('Elon Musk', '6.4%', 0.1036515012383461),
#  ('Elon Musk', 'the 12 months', 0.05875646322965622),
#  ('Elon Musk', 'the end of March', 0.26924774050712585),
#  ('Elon Musk', 'Twitter', 0.4021254777908325),
#  ('Elon Musk', '44bn', 0.16014322638511658),
#  ('Elon Musk', 'Tesla', 0.5186994075775146),
#  ('Elon Musk', 'Musk', 0.7010902166366577),
#  ('Elon Musk', 'Ukraine', 0.49591439962387085),
#  ('Elon Musk', 'Musk', 0.5812006592750549),
#  ('Elon Musk', 'several months', 0.03978922218084335),
#  ('Elon Musk', 'Musk', 0.6627101302146912),
#  ('Elon Musk', 'Twitter', 0.4962574541568756)]

# %%
# convert tupils to dataframe to clean up
df = pd.DataFrame(similar_words, columns =['first', 'second', 'score'])
df.head()
# Out:
#        first         second     score
# 0  this week      this week  1.000000
# 1  this week      Elon Musk  0.136226
# 2  this week  the past year  0.401289
# 3  this week           Musk  0.080037
# 4  this week        Twitter -0.002061

# %%
# organize dataframe by score value (after removing duplicates)
df = df.sort_values(['score'], ascending = [False])
df = df.drop_duplicates()

df.head(50)
# Out:
#                   first              second     score
# 0             this week           this week  1.000000
# 52        the past year       the past year  1.000000
# 404             Twitter             Twitter  1.000000
# 390    the end of March    the end of March  1.000000
# 364       the 12 months       the 12 months  1.000000
# 338                6.4%                6.4%  1.000000
# 286                  US                  US  1.000000
# 260      a year earlier      a year earlier  1.000000
# 234         199 million         199 million  1.000000
# 208         229 million         229 million  1.000000
# 182               Daily               Daily  1.000000
# 156                 513                 513  1.000000
# 130  the latest quarter  the latest quarter  1.000000
# 98                 Musk                Musk  1.000000
# 442                44bn                44bn  1.000000
# 572      several months      several months  1.000000
# 468               Tesla               Tesla  1.000000
# 520             Ukraine             Ukraine  1.000000
# 312               18.1%               18.1%  1.000000
# 26            Elon Musk           Elon Musk  1.000000
# 209         229 million         199 million  0.857900
# 233         199 million         229 million  0.857900
# 44            Elon Musk                Musk  0.701090
# 476                Musk           Elon Musk  0.701090
# 576                Musk           Elon Musk  0.662710
# 48            Elon Musk                Musk  0.662710
# 541                Musk             Twitter  0.659331
# 421             Twitter                Musk  0.659331
# 159                 513         199 million  0.633864
# 231         199 million                 513  0.633864
# 337                6.4%               18.1%  0.622902
# 313               18.1%                6.4%  0.622902
# 119             Twitter                Musk  0.618186
# 479                Musk             Twitter  0.618186
# 36            Elon Musk                  US  0.613305
# 276                  US           Elon Musk  0.613305
# 158                 513         229 million  0.603336
# 206         229 million                 513  0.603336
# 403             Twitter                Musk  0.602000
# 91                 Musk             Twitter  0.602000
# 76                 Musk           Elon Musk  0.591898
# 28            Elon Musk                Musk  0.591898
# 511             Ukraine                  US  0.583344
# 295                  US             Ukraine  0.583344
# 65        the past year    the end of March  0.581812
# 377    the end of March       the past year  0.581812
# 526                Musk           Elon Musk  0.581201
# 46            Elon Musk                Musk  0.581201
# 372       the 12 months      several months  0.564310
# 564      several months       the 12 months  0.564310
